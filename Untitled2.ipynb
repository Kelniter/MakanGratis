# %% [markdown]
# <a href="https://colab.research.google.com/github/Kelniteru/MakanGratis/blob/ular/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot([1, 2, 3, 4])
plt.tight_layout();

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Your plot creation code here (e.g., plt.plot() for line graphs)

plt.plot(range(10))

plt.tight_layout()

from IPython.core.display import HTML

HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")

# Display the plot
plt.show()

# %%
# prompt: made me a single line plot in matplotlib but have left padding 5px

import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], linewidth=5)
plt.tight_layout()
plt.gca().set_xbound(lower=0.5, upper=4.5)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

fig.patch.set_alpha(0.0)

plt.plot(range(10));

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.tight_layout()
fig = plt.gcf()
fig.set_facecolor('none');

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.tight_layout()
fig = plt.gcf()
fig.set_facecolor('none')
